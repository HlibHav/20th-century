# %% [markdown]
# # 1.6 Intro to NLP and Network Analysis

# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module

# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# zsh:1: parse error near `-m'

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %%
import pycountry

# We get a list of country names
country_list = [country.name for country in pycountry.countries]

print("Loaded", len(country_list), "countries")
print(country_list[:10])  # Check first 10
# Out:
# Loaded 249 countries
# ['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Åland Islands', 'Albania', 'Andorra', 'United Arab Emirates', 'Argentina', 'Armenia']

# %% [markdown]
# ## Load 20 century events

# %%
# Load the book

with open('20Cent copy.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %% [markdown]
# ### Text wrangling

# %%
import re

# Preperation
# with open("your_file.txt", "r", encoding="utf-8") as f:
#     data = f.read()

# 1️⃣ Detect special characters
special_chars = re.findall(r"[^\w\s]", data)
unique_special = sorted(set(special_chars))

print("🔹 Special characters found:")
print(f"- Total special characters: {len(special_chars)}")
print(f"- Unique special characters: {unique_special}")



#The text in the lower case
data_lower = data.lower()

#Let's find the countries that are partially mentioned
found_countries = []
for c in country_list:
    if c.lower() in data_lower:
        found_countries.append(c)

missing_countries = sorted(set(country_list) - set(found_countries))

print("\n🔹 Country analysis:")
print(f"- Countries found ({len(found_countries)}): {found_countries}")
print(f"- Missing countries ({len(missing_countries)}): {missing_countries}")
print(f"- Coverage: {len(found_countries)}/{len(country_list)} countries "
      f"({(len(found_countries)/len(country_list))*100:.1f}%)")
# Out:
# 🔹 Special characters found:
# - Total special characters: 2432
# - Unique special characters: ['"', '&', "'", '(', ')', ',', '-', '.', '/', ':', ';', '?', '[', ']', '|', '®', '–', '—']
#
# 🔹 Country analysis:
# - Countries found (35): ['Afghanistan', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Bulgaria', 'Bosnia and Herzegovina', 'Canada', 'China', 'Cuba', 'Germany', 'Egypt', 'Spain', 'France', 'United Kingdom', 'Hong Kong', 'Hungary', 'India', 'Ireland', 'Israel', 'Italy', 'Jordan', 'Japan', 'Mali', 'Montenegro', 'New Zealand', 'Oman', 'Pakistan', 'Poland', 'Romania', 'Rwanda', 'Slovakia', 'Ukraine', 'United States', 'South Africa']
# - Missing countries (214): ['Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Aruba', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia, Plurinational State of', 'Bonaire, Sint Eustatius and Saba', 'Botswana', 'Bouvet Island', 'Brazil', 'British Indian Ocean Territory', 'Brunei Darussalam', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo', 'Congo, The Democratic Republic of the', 'Cook Islands', 'Costa Rica', 'Croatia', 'Curaçao', 'Cyprus', 'Czechia', "Côte d'Ivoire", 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland', 'French Guiana', 'French Polynesia', 'French Southern Territories', 'Gabon', 'Gambia', 'Georgia', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Heard Island and McDonald Islands', 'Holy See (Vatican City State)', 'Honduras', 'Iceland', 'Indonesia', 'Iran, Islamic Republic of', 'Iraq', 'Isle of Man', 'Jamaica', 'Jersey', 'Kazakhstan', 'Kenya', 'Kiribati', "Korea, Democratic People's Republic of", 'Korea, Republic of', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia, Federated States of', 'Moldova, Republic of', 'Monaco', 'Mongolia', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island', 'North Macedonia', 'Northern Mariana Islands', 'Norway', 'Palau', 'Palestine, State of', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Portugal', 'Puerto Rico', 'Qatar', 'Russian Federation', 'Réunion', 'Saint Barthélemy', 'Saint Helena, Ascension and Tristan da Cunha', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Martin (French part)', 'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Georgia and the South Sandwich Islands', 'South Sudan', 'Sri Lanka', 'Sudan', 'Suriname', 'Svalbard and Jan Mayen', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan, Province of China', 'Tajikistan', 'Tanzania, United Republic of', 'Thailand', 'Timor-Leste', 'Togo', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Türkiye', 'Uganda', 'United Arab Emirates', 'United States Minor Outlying Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, Bolivarian Republic of', 'Viet Nam', 'Virgin Islands, British', 'Virgin Islands, U.S.', 'Wallis and Futuna', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe', 'Åland Islands']
# - Coverage: 35/249 countries (14.1%)

# %%
# Clean text and save 
if len(unique_special) > 0 or len(missing_countries) > 0:
    cleaned_text = re.sub(r'[^\w\s]', '', data)
    try:
        with open('cleaned_data.txt', 'w', encoding='utf-8') as f:
            f.write(cleaned_text)
    except IOError as e:
        print(f"Error writing to file: {e}")

# %%
book = NER(data)

# %%
# Visualize identified entities

displacy.render(book, style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> WikipediaThe Free EncyclopediaSearchDonateCreate accountLog inContents  hide(Top)SummaryNature of innovation and changeSocial changeEarth at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of the 20th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  centuryWars and politicsCulture and entertainmentScienceEngineering and technologyReligionEconomicsSee alsoReferencesSourcesFurther readingExternal links20th century171 languagesArticleTalkReadEditView historyToolsAppearance  hideTextSmallStandardLargeWidthStandardWideColor (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     beta)AutomaticLightDarkFrom Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the free encyclopediaFor other uses, see
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (disambiguation).Earthrise, taken on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 24, 1968
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by astronaut
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William &quot;Bill&quot; Anders
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  during the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apollo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  space mission. It was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  photograph taken of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  from lunar orbit.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Millennia2nd millenniumCenturies19th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     century 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21st centuryTimelines19th century 20th century 21st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  centuryState
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     leaders19th century 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  21st centuryDecades1900s
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1910s 1920s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  1930s
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1940s1950s 1960s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  1970s
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1980s 1990sCategories
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :Births – DeathsEstablishments –
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DisestablishmentsvteThe 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  began on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 January 1901
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MCMI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), and ended on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     31 December 2000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (MM).[1][2] It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 10th and last century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 2nd millennium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and was marked by new models of scientific understanding, unprecedented scopes of warfare, new modes of communication that would operate at nearly instant speeds, and new forms of art and entertainment. Population growth was also unpreceden

# %% [markdown]
# ## Get named entity list per sentence

# %%
# Empty list for results
df_sentences = []

# Go through all the sentences
for sent in book.sents:
    # Collect the list of entities in the sentence
    entity_list = [ent.text for ent in sent.ents]
    
    # Add a dictionary to the list
    df_sentences.append({
        "sentence": sent.text,
        "entities": entity_list
    })

# Convert a list to a DataFrame
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0
# 1                                       WikipediaThe
# 2  Free EncyclopediaSearchDonateCreate accountLog...
# 3  It was the first photograph taken of Earth fro...
# 4  Millennia2nd millenniumCenturies19th century 2...
# 5  centuryState leaders19th century 20th century ...
# 6  Population growth was also unprecedented,[3] a...
# 7  Unprecedented advances in science and technolo...
# 8  The Earth's sixth mass extinction event, the H...
# 9  Major themes of the century included decoloniz...
#
#                                             entities
# 0                                                 []
# 1                                                 []
# 2  [the end of the 20th, beta)AutomaticLightDarkF...
# 3                                     [first, Earth]
# 4  [Millennia2nd millenniumCenturies19th, century...
# 5  [leaders19th century 20th century, 1910s 1920s...
# 6  [the century, around 1.6 billion, 20th century...
# 7                                      [the century]
# 8                           [Earth, sixth, Holocene]
# 9                                      [the century]

# %% [markdown]
# ## Country filter

# %%
countries = found_countries
def filter_entities(entity_list, allowed_entities):
    allowed_lower = [c.lower() for c in allowed_entities]
    filtered_entities = [
        ent for ent in entity_list
        if any(c in ent.lower() for c in allowed_lower)
    ]
    print("Filtered entities:", filtered_entities)
    return filtered_entities

# %%
df_sentences["filtered_entities"] = df_sentences["entities"].apply(
    lambda ents: filter_entities(ents, countries)
)
# filtration 
df_sentences_filtered = df_sentences[df_sentences["filtered_entities"].map(len) > 0]
# Out:
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['France', 'the United States', 'Italy', 'Romania', 'Germany', 'Austria', 'Hungary', 'the Ottoman Empire', 'Bulgaria']
# Filtered entities: ['Germany']
# Filtered entities: ['Ottoman']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Italy', 'Germany', 'Spain', "Nazi Germany's"]
# Filtered entities: ['Japan', 'Germany', 'Italy']
# Filtered entities: ['Japan', 'the United States', 'Germany', 'Poland', 'the United States', 'the United Kingdom', 'Canada', 'France']
# Filtered entities: ['Japan']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Germany']
# Filtered entities: ['East Germany']
# Filtered entities: ['the United States']
# Filtered entities: ['France', 'the United States']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['China', 'Cuba', 'Afghanistan']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['China', 'Cuba']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['South Africa']
# Filtered entities: []
# Filtered entities: ['the Republic of India', 'India']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Indian']
# Filtered entities: ['China']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['China', 'India']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['1945.[22]Russo-Japanese War', 'the Empire of Japan']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Armenian', 'Armenians', 'the Ottoman Empire', 'Japan', 'United Kingdom of Great Britain', 'Ireland', 'United States of America', 'China']
# Filtered entities: ['Germany', 'France', 'Italy', 'Japan', 'the United States']
# Filtered entities: []
# Filtered entities: ['Ottoman']
# Filtered entities: ['Egypt', 'the Ottoman Empire', 'the Ottoman Empire']
# Filtered entities: []
# Filtered entities: ['Austrian', 'the Kingdom of Bulgaria', 'Ottoman']
# Filtered entities: ['the United States']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Soviet Ukraine']
# Filtered entities: ['Nazi Germany']
# Filtered entities: ['Spain']
# Filtered entities: []
# Filtered entities: ['Nazi Germany', 'Fascist Italy', 'the Empire of Japan', 'China', 'France', 'the United Kingdom', 'the United States']
# Filtered entities: []
# Filtered entities: ['Japan']
# Filtered entities: ['Israel', 'Israelis']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['China', 'Indochina', 'Cuba']
# Filtered entities: ['the United States']
# Filtered entities: []
# Filtered entities: ['Indian', 'India', 'Pakistan']
# Filtered entities: ['China']
# Filtered entities: ["People's Republic of China"]
# Filtered entities: ['China']
# Filtered entities: ['Indian', 'the United States', 'South Africa']
# Filtered entities: ['the United States', 'China']
# Filtered entities: ['Hong Kong']
# Filtered entities: []
# Filtered entities: ['the United States', 'Italy', 'Cuba']
# Filtered entities: ['Israel', 'Egypt', 'Jordan']
# Filtered entities: []
# Filtered entities: ['Israel', 'Egypt']
# Filtered entities: ['Afghanistan', 'Poland']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Czechoslovakia']
# Filtered entities: ['East Germany', 'West Germany', 'China']
# Filtered entities: []
# Filtered entities: ['Bosnia and Herzegovina', 'Rwandan']
# Filtered entities: ['France', 'Germany']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['the United States']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['the United States']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Argentina']
# Filtered entities: ['the United States']
# Filtered entities: []
# Filtered entities: ['the United States']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Fernanda Montenegro']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['the United States']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Japan', 'the United States']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['the United States']
# Filtered entities: []
# Filtered entities: ['The United States']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['United States']
# Filtered entities: ['the United States', 'Canada', 'Australia', 'New Zealand']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Americanized" Australia']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['The Indian Express']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['United States Census Bureau']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['United States Census Bureau']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['China']
# Filtered entities: []
# Filtered entities: ['The Indochina Wars:']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Armenian']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: ['Armenian']
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []
# Filtered entities: []

# %%
# check results 
print("Sentences with filtered entities:")
print(df_sentences_filtered)
# Out:
# Sentences with filtered entities:
#                                               sentence  \
# 21   After more than four years of trench warfare i...
# 22   In addition to annexing many of the colonial p...
# 23   The Austro-Hungarian and Ottoman empires were ...
# 26   Fascism, a movement which grew out of post-war...
# 27   Meanwhile, Japan had rapidly transformed itsel...
# ..                                                 ...
# 368                       United States Census Bureau.
# 413  May 11, 2003 "China's great famine: 40 years l...
# 415                               "The Indochina Wars:
# 502  [Understanding the Armenian genocide: 1915 to ...
# 505  "They Can Live in the Desert but Nowhere Else"...
#
#                                               entities  \
# 21   [more than four years, Western Europe, up to, ...
# 22                       [the Triple Entente, Germany]
# 23                                           [Ottoman]
# 26   [the Great Depression of the 1930s, Italy, Ger...
# 27                       [Japan, Germany, Italy, Axis]
# ..                                                 ...
# 368                      [United States Census Bureau]
# 413              [May 11, 2003, China, 40 years later]
# 415                              [The Indochina Wars:]
# 502          [Armenian, 1915, the present day, French]
# 505            [They Can Live in the Desert, Armenian]
#
#                                      filtered_entities
# 21   [France, the United States, Italy, Romania, Ge...
# 22                                           [Germany]
# 23                                           [Ottoman]
# 26             [Italy, Germany, Spain, Nazi Germany's]
# 27                             [Japan, Germany, Italy]
# ..                                                 ...
# 368                      [United States Census Bureau]
# 413                                            [China]
# 415                              [The Indochina Wars:]
# 502                                         [Armenian]
# 505                                         [Armenian]
#
# [68 rows x 3 columns]

# %% [markdown]
# ## Create relationships

# %%
# Parameter: size of the sentence window
window_size = 5

# Empty list for connections
relationships = []

# Check if there are any strings at all
if not df_sentences_filtered.empty:

    # Go through the row indices
    for i in range(df_sentences_filtered.index[-1]):
        end_i = min(i + window_size, df_sentences_filtered.index[-1])

        # Collect all countries in this window
        country_list = sum(
            (df_sentences_filtered.loc[i:end_i, "filtered_entities"]),
            []
        )

        # Remove consecutive repetitions
        country_unique = [
            country_list[j]
            for j in range(len(country_list))
            if j == 0 or country_list[j] != country_list[j-1]
        ]

        # Creating pairs
        if len(country_unique) > 1:
            for idx, a in enumerate(country_unique[:-1]):
                b = country_unique[idx + 1]
                relationships.append({"source": a, "target": b})

else:
    print("❌ DataFrame порожній — немає речень із країнами.")

# Convert a list to a DataFrame
relationships_df = pd.DataFrame(relationships)

# Check the result
print("✅ created relationships_df:")
print(relationships_df.head())
# Out:
# ✅ created relationships_df:
#               source             target
# 0             France  the United States
# 1  the United States              Italy
# 2              Italy            Romania
# 3            Romania            Germany
# 4            Germany            Austria

# %%
relationship_df = pd.DataFrame(relationships) 
relationship_df = pd.DataFrame(
    np.sort(relationship_df.values, axis=1),
    columns=relationship_df.columns
)
relationship_df["value"] = 1

relationship_df = relationship_df.groupby(
    ["source", "target"], as_index=False
).sum()
relationship_df.head(20)
# Out:
#                          source                   target  value
# 0   1945.[22]Russo-Japanese War      the Empire of Japan      6
# 1                   Afghanistan                     Cuba      6
# 2                   Afghanistan                    Egypt      5
# 3                   Afghanistan                   Poland      6
# 4                     Argentina        the United States      5
# 5                      Armenian                Armenians      6
# 6                     Armenians       the Ottoman Empire      6
# 7                     Australia                   Canada      6
# 8                     Australia              New Zealand      6
# 9                       Austria                  Germany      6
# 10                      Austria                  Hungary      6
# 11                     Austrian  the Kingdom of Bulgaria      6
# 12                     Austrian       the Ottoman Empire      4
# 13       Bosnia and Herzegovina                    China      4
# 14       Bosnia and Herzegovina                  Rwandan      6
# 15                     Bulgaria                  Germany      5
# 16                     Bulgaria       the Ottoman Empire      6
# 17                       Canada                   France      6
# 18                       Canada       the United Kingdom      6
# 19                       Canada        the United States      6

# %%
relationship_df.to_csv('20Cent.csv')
